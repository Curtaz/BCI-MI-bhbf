# %%
from scipy.io import loadmat

subj = loadmat(r'C:\Users\tomma\Documents\Uni\PhD\data\cBCI\sbj4_tr_rigorous\preprocessed\dataset_train.mat')

# %%
subj = fix_array(subj['subj'])
# Out:
# eeg None
# triggers ('pos', 'type')
# pos None
# type None
# session_delims None

# %%
subj['triggers']['type']
# Out:
# array([array([[  1],
#               [786],
#               [773],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [773],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [773],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [773],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [773],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [771],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [771],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [783],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [783],
# ...

# %%
new_data['EVENT']['TYP']
# Out:
# array([array([[  1],
#               [786],
#               [773],
#               [781],
#               [898],
#               [  1],
#               [786],
#               [773],
#               [781],
#               [898],
#               [  1],
#               [786],
#               [771],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [783],
#               [781],
#               [898],
#               [  1],
#               [786],
#               [773],
#               [781],
#               [898],
#               [  1],
#               [786],
#               [771],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [773],
#               [781],
#               [898],
#               [  1],
#               [786],
#               [771],
#               [781],
#               [897],
#               [  1],
#               [786],
#               [771],
# ...
